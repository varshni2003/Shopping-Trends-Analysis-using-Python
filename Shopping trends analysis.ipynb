# %% [markdown]
# ## SHOPPING TRENDS ANALYSIS ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action='ignore')
colors = ["#89CFF0", "#FF69B4", "#FFD700", "#7B68EE", "#FF4500",
          "#9370DB", "#32CD32", "#8A2BE2", "#FF6347", "#20B2AA",
          "#FF69B4", "#00CED1", "#FF7F50", "#7FFF00", "#DA70D6"]

# %% [markdown]
# ## Reading the dataset  ##

# %%
df= pd.read_csv("E:\data analysis project\Shopping trends analysis\shopping_trends.csv")

# %% [markdown]
# ## Exploratry data analysis ##

# %% [markdown]
# Display top 5 rows of the dataset

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# Display last 5 rows of the dataset

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                     28    Virginia    L  Turquoise  Summer
# 3896                     49        Iowa    L      White  Spring
# 3897                     33  New Jersey    L      Green  Spring
# 3898                     77   Minnesota    S      Brown  Summer
# 3899                     81  California    M      Beige  Spring
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 3895            4.2                  No           Cash  2-Day Shipping
# 3896            4.5                  No         PayPal    Store Pickup
# ...

# %% [markdown]
# Print random 5 rows of the dataset

# %%
df.sample(5)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 610           611   53    Male         Shorts     Clothing
# 414           415   29    Male       Backpack  Accessories
# 58             59   69    Male         Hoodie     Clothing
# 3159         3160   62  Female            Hat  Accessories
# 1495         1496   45    Male        Jewelry  Accessories
#
#       Purchase Amount (USD)      Location Size     Color  Season  \
# 610                      72      Oklahoma    M  Charcoal  Summer
# 414                      88       Wyoming    L    Violet  Winter
# 58                       54      Missouri    M  Charcoal  Summer
# 3159                     89     Louisiana    L      Pink  Winter
# 1495                     23  Rhode Island    M     Brown  Winter
#
#       Review Rating Subscription Status Payment Method  Shipping Type  \
# 610             2.5                 Yes     Debit Card  Free Shipping
# 414             2.6                 Yes  Bank Transfer   Store Pickup
# ...

# %% [markdown]
# Columns in dataset

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# Find shape of dataset

# %%
df.shape
# Out:
# (3900, 19)

# %% [markdown]
# Check missing values in dataset

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Get overall statistics of dataset

# %%
pd.options.display.float_format = '{:.2f}'.format
df.describe()
# Out:
#        Customer ID     Age  Purchase Amount (USD)  Review Rating  \
# count      3900.00 3900.00                3900.00        3900.00
# mean       1950.50   44.07                  59.76           3.75
# std        1125.98   15.21                  23.69           0.72
# min           1.00   18.00                  20.00           2.50
# 25%         975.75   31.00                  39.00           3.10
# 50%        1950.50   44.00                  60.00           3.70
# 75%        2925.25   57.00                  81.00           4.40
# max        3900.00   70.00                 100.00           5.00
#
#        Previous Purchases
# count             3900.00
# mean                25.35
# std                 14.45
# min                  1.00
# 25%                 13.00
# 50%                 25.00
# 75%                 38.00
# max                 50.00

# %% [markdown]
# ## Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement  ##

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %% [markdown]
# ## Descriptive Analytics Questions

# %% [markdown]
# #### 1.What is the overall distribution of customer ages in the dataset?

# %%
plt.hist(df['Age'], bins= 10, edgecolor= 'k')
plt.title("Ditistribution of Customer Age")
plt.ylabel("Number of Customer")
plt.xlabel('Age')
plt.show()

# %% [markdown]
# #### 2. What is the gender distribution of customers in the dataset?

# %%
plt.figure(figsize=(5,3))
sns.countplot(x='Gender',data=df,width=0.5 , palette=colors)
plt.title('Distribution Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# #### 3. What are the most frequently purchased items (top products) in the dataset?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
sns.countplot(y='Item Purchased',data=df , palette=colors)
plt.title(' Product  Purchased ');

# %%
df['Item Purchased'].value_counts().sort_values(ascending=False).head().plot(kind='bar',color=('pink','green','yellow','orange','brown'))
plt.title('Top 5 Most Purchased Products')
plt.xlabel("Item Purchased")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 4. How are the purchases distributed across different categories of items (e.g., clothing, accessories, shoes)?

# %%
sns.countplot(x='Category',data=df, palette= colors)
plt.title('Purchases based on Category ')
plt.show()

# %% [markdown]
# #### 5. What is the average purchase amount in USD, and how does it vary across different categories of items?

# %%
df.groupby('Category')['Purchase Amount (USD)'].mean()
# Out:
# Category
# Accessories   59.84
# Clothing      60.03
# Footwear      60.26
# Outerwear     57.17
# Name: Purchase Amount (USD), dtype: float64

# %%
sns.barplot(x='Category',y='Purchase Amount (USD)',data=df, palette= colors)
# Out:
# <Axes: xlabel='Category', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# #### 6. What are the most popular sizes and colors for purchased items?

# %%
df['Color'].value_counts().sort_values(ascending=False).head(10).plot(kind="bar",color='pink')
plt.title("The Top Ten Colors of purchased items")
plt.xlabel("Colors")
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### 7. Can you identify any seasonal shopping trends based on the "Season" column?

# %%
df['Season'].value_counts().plot()
plt.title('Purchased Items by Season')
plt.xlabel('Season')
plt.ylabel('Count');

# %% [markdown]
# #### 8. What is the distribution of review ratings given by customers?

# %%
sns.histplot(df['Review Rating'],bins=20)
plt.figure(figsize=(20,5))

# %% [markdown]
# #### 9. What percentage of customers have a subscription, and does subscription status impact purchase behavior?

# %%
no_of_subscribers=(df['Subscription Status']=='Yes').sum()
Total_no_of_customers=len(df)
percentage_of_subscribers=(no_of_subscribers*100)/Total_no_of_customers
print('Subscribers percentage =',percentage_of_subscribers,'%')
df.groupby('Subscription Status')['Subscription Status']._value_counts().plot(kind="pie")
plt.ylabel('')
plt.title('Subscription Status')
# Out:
# Subscribers percentage = 27.0 %
# Text(0.5, 1.0, 'Subscription Status')

# %% [markdown]
# #### 10. What are the preferred shipping types among customers, and do they correlate with the purchase amount or frequency?

# %%
df['Shipping Type'].unique()
# Out:
# array(['Express', 'Free Shipping', 'Next Day Air', 'Standard',
#        '2-Day Shipping', 'Store Pickup'], dtype=object)

# %%
df.groupby('Shipping Type')['Purchase Amount (USD)'].sum().plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='Shipping Type'>

# %%
df.groupby('Shipping Type')['Frequency of Purchases'].value_counts()
# Out:
# Shipping Type   Frequency of Purchases
# 2-Day Shipping  Every 3 Months             97
#                 Monthly                    95
#                 Quarterly                  93
#                 Fortnightly                89
#                 Bi-Weekly                  87
#                 Annually                   84
#                 Weekly                     82
# Express         Bi-Weekly                 100
#                 Every 3 Months             99
#                 Annually                   96
#                 Weekly                     94
#                 Fortnightly                88
#                 Quarterly                  85
#                 Monthly                    84
# Free Shipping   Annually                  112
#                 Weekly                    110
#                 Every 3 Months            101
#                 Quarterly                 101
#                 Monthly                    90
# ...

# %% [markdown]
# #### 11. How frequently are discounts applied, and does this impact the purchase amount?

# %%
sns.countplot(x='Discount Applied',data=df, palette= colors)
plt.title('Discounts')
# Out:
# Text(0.5, 1.0, 'Discounts')

# %%
sns.barplot(x='Discount Applied',y='Purchase Amount (USD)',data=df, palette= colors)
# Out:
# <Axes: xlabel='Discount Applied', ylabel='Purchase Amount (USD)'>

# %% [markdown]
# #### 12. How often do customers use promo codes, and does it vary by gender or age group?

# %%
sns.countplot(x='Promo Code Used',data=df)
plt.title('Promo code users')
# Out:
# Text(0.5, 1.0, 'Promo code users')

# %%
sns.countplot(x='Promo Code Used',data=df,hue='Gender')
plt.title('Promo code user based on gender')
# Out:
# Text(0.5, 1.0, 'Promo code user based on gender')

# %% [markdown]
# #### Diagnostic Analytics Questions:

# %% [markdown]
# #### 1. Are there any significant differences in purchase behavior between male and female customers?

# %%
sns.barplot(x='Gender',y='Previous Purchases',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Previous Purchases'>

# %% [markdown]
# #### 2. Can you identify any patterns in the frequency of purchases (e.g., weekly, fortnightly, monthly) and how they relate to other variables like age or gender?

# %%
sns.lineplot(x='Frequency of Purchases',y='Age',data=df,hue='Gender')
plt.title('Frequency of Purchases based on Gender')
# Out:
# Text(0.5, 1.0, 'Frequency of Purchases based on Gender')

# %% [markdown]
# #### 3. Are there specific categories or items that are more likely to lead to high or low review ratings?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.groupby("Category")['Review Rating'].mean()
# Out:
# Category
# Accessories   3.77
# Clothing      3.72
# Footwear      3.79
# Outerwear     3.75
# Name: Review Rating, dtype: float64

# %%
sns.barplot(x='Category',y='Review Rating',data= df, palette= colors)
plt.figure(figsize=(10,3))

# %% [markdown]
# #### 4. Is there a relationship between having a subscription and making more frequent purchases?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.groupby('Frequency of Purchases')['Subscription Status'].value_counts().plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='Frequency of Purchases,Subscription Status'>

# %% [markdown]
# #### 5. Does the choice of shipping type impact the purchase amount, and are there geographical variations in shipping preferences?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
sns.barplot(x='Shipping Type', y='Purchase Amount (USD)', data=df)
plt.title('Purchase Amount by Shipping Type')
plt.xticks(rotation =90)
plt.xlabel('Purchase Amount (USD)')
plt.ylabel('Shipping Type')
plt.figure(figsize=(10,3))

plt.show()

# %% [markdown]
# #### 6.Are there any interesting insights related to the use of promo codes, such as which customer segments use them more frequently?

# %%
plt.title('Frequency of Purchases vs Promo Code Used ')
sns.countplot(x='Frequency of Purchases',hue='Promo Code Used',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='Promo Code Used',data=df,hue="Gender", palette= colors)
# Out:
# <Axes: xlabel='Promo Code Used', ylabel='count'>

# %% [markdown]
# #### 7. How do items with discounts applied compare to those without in terms of purchase amount and frequency?

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.groupby('Discount Applied')['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.show()
df.groupby('Discount Applied')['Purchase Amount (USD)'].mean()
# Out:
# Discount Applied
# No    60.13
# Yes   59.28
# Name: Purchase Amount (USD), dtype: float64

# %%
df.pivot_table(index ="Discount Applied",values='Purchase Amount (USD)',aggfunc=['mean','sum'])
df.pivot_table(index ="Frequency of Purchases",values='Purchase Amount (USD)',aggfunc=['mean','sum'])
df.pivot_table(index =["Frequency of Purchases","Discount Applied"],values='Purchase Amount (USD)',aggfunc=['mean','sum'])
# Out:
#                                                          mean  \
#                                         Purchase Amount (USD)
# Frequency of Purchases Discount Applied
# Annually               No                               60.67
#                        Yes                              59.47
# Bi-Weekly              No                               60.53
#                        Yes                              60.92
# Every 3 Months         No                               60.69
#                        Yes                              59.32
# Fortnightly            No                               59.63
#                        Yes                              58.34
# Monthly                No                               59.53
#                        Yes                              59.07
# Quarterly              No                               60.21
#                        Yes                              59.68
# ...

# %% [markdown]
# ### Descriptive Analytics Questions for Business Improvement:

# %% [markdown]
# #### 1. What is the average purchase amount (in USD) per customer, and how can it be increased?

# %%
mean_purchse_amount=df.groupby('Customer ID')['Purchase Amount (USD)'].mean()
mean_purchse_amount=mean_purchse_amount.astype(int)
mean_purchse_amount
# Out:
# Customer ID
# 1       53
# 2       64
# 3       73
# 4       90
# 5       49
#         ..
# 3896    28
# 3897    49
# 3898    33
# 3899    77
# 3900    81
# Name: Purchase Amount (USD), Length: 3900, dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# #### 2. Can we identify the most profitable categories and items, and should we focus more on promoting them?

# %%
df.groupby('Category')['Purchase Amount (USD)'].sum().plot(kind='pie')
plt.ylabel('')
plt.title("Most Profitable Categories")
# Out:
# Text(0.5, 1.0, 'Most Profitable Categories')

# %%
df.groupby('Item Purchased')['Purchase Amount (USD)'].sum().sort_values(ascending=False).plot(kind='bar',color=colors)
plt.title("Most Profitable Items")
plt.ylabel('Purchase Amount (USD)')
# Out:
# Text(0, 0.5, 'Purchase Amount (USD)')
